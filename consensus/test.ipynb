# %%
from methods import Model, ADOM_PLUS
import utils
import matplotlib.pyplot as plt

# %%
nodes = 20
dim = 100

# %%
model = Model(nodes, dim)
# Out:
# graph chi: 41.272092770951986
# mu= 0.9999999999999732
# chitA 2.0
# muH 0.0015, LH 2.0

# %%
x_f, y_f, z_f, f_err, cons_err, dist = ADOM_PLUS(iters=1000, model=model)

# %%
plt.plot(f_err)
plt.yscale('log')
